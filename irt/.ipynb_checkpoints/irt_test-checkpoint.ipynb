# %%
using PyPlot
theta = collect(-4:0.1:4)
icc = 1.0 ./(1.0 .+ exp.(-2.0.*(theta .- 0.0)))

plot(theta, icc)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Array{PyCall.PyObject,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x12ff32780>

# %%
function(theta, a::Float64, b::Float64, D::Float64) icc2pl::Float64
    1.0 ./(1.0 .+ exp.(-a .* (theta .- b)))
end
# Out:
# #13 (generic function with 1 method)

# %%
icc2pl(theta, 1.0, 1.5, 1.7)
# Out:
# UndefVarError: icc2pl not defined
#
# Stacktrace:
#  [1] top-level scope at In[16]:1
